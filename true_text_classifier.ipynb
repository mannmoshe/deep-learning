# %% [markdown]
# <a href="https://colab.research.google.com/github/mannmoshe/deep-learning/blob/main/true_text_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import random

# %%
req = requests.get("https://raw.githubusercontent.com/mannmoshe/text-recognition/main/torah_text.txt")
req.encoding = 'ISO-8859-8'
torah_text = req.text

# %%
torah_words = torah_text.split()

# %%
phrases = {}
for i in range(0, int(len(torah_words)), 3):
  phrase = ''.join(torah_words[i: i+3])
  phrases[phrase] = 1 # true text
  phrases[''.join(random.choices(phrase, k=len(phrase)))] = 0 # random text

# %%
phrases
# Out:
# {'בראשיתבראאלהים': 1,
#  'יאאיהיייאשיהלם': 0,
#  'אתהשמיםואת': 1,
#  'תשמהאתאווא': 0,
#  'הארץוהארץהיתה': 1,
#  'ץרהואארההיורת': 0,
#  'תהוובהווחשך': 1,
#  'והווהתושוךת': 0,
#  'עלפניתהום': 1,
#  'נםותהוםוע': 0,
#  'ורוחאלהיםמרחפת': 1,
#  'ילחחםמילתתלררי': 0,
#  'עלפניהמים': 1,
#  'למהלעמהנפ': 0,
#  'ויאמראלהיםיהי': 1,
#  'יילוהיההיאמיה': 0,
#  'אורויהיאור': 1,
#  'רוריאיריאי': 0,
#  'ויראאלהיםאת': 1,
#  'תלאאאראוםרם': 0,
#  'האורכיטוב': 1,
#  'וההוהוכאכ': 0,
#  'ויבדלאלהיםבין': 1,
#  'הבןייןהבהלאוב': 0,
#  'האורוביןהחשך': 1,
#  'הבןוךיווהךוו': 0,
#  'ויקראאלהיםלאור': 1,
#  'אאאהקולאליראוי': 0,
#  'יוםולחשךקרא': 1,
#  'יליאךקשוולק': 0,
#  'לילהויהיערב': 1,
#  'הבליהברלליו': 0,
#  'ויהיבקריום': 1,
#  'קיובירםרבר': 0,
#  'אחדויאמראלהים': 1,
#  'ודרםאיהחאמאאה': 0,
#  'יהירקיעבתוך': 1,
#  'בעיהעהךךביר': 0,
#  'המיםויהימבדיל': 1,
#  'ידמהימלםממההו': 0,
#  'ביןמיםלמים': 1,
#  'ימןלמןמבמם': 0,
#  'ויעשאלהיםאת': 1,
#  'עםליאאהאאאת': 0,
#  'הרקיעויבדלבין': 1,
#  'הקההבןבןבברול': 0,
# ...
